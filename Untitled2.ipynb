# %% [markdown]
# <a href="https://colab.research.google.com/github/naveenraj208/ml-lab-1/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

V1 = [random.random() for _ in range(100)]

V1.sort()

print(V1)
# Out:
# [0.00650938769337317, 0.017223899505941054, 0.02035454639514933, 0.02592395522879898, 0.027792404535943005, 0.0399402986852877, 0.04362582417400773, 0.09467369752953525, 0.10877002030224747, 0.11020251083263233, 0.1251855321159845, 0.1263756591707127, 0.13435640280480154, 0.14336763863015012, 0.15870958809332936, 0.15891204077278498, 0.16609254514533367, 0.1813036567522217, 0.1876726522755804, 0.1905991628588345, 0.19093224895105576, 0.20899805365269253, 0.21261260029907025, 0.21289237156108642, 0.2282218151672003, 0.22996850719419804, 0.23071176850884256, 0.23775503870707937, 0.24373811360160524, 0.24589336368024572, 0.26148014247600315, 0.27741629065151086, 0.2830863743337192, 0.31785663248735396, 0.32925766226146624, 0.348318339815314, 0.34919229623792436, 0.349742016502949, 0.36930620912814904, 0.37883358225771413, 0.4003440456019416, 0.40035497017083965, 0.41700411307669516, 0.42099911869050377, 0.4236643610885711, 0.44209278065405944, 0.44341659311479253, 0.4466532031383549, 0.
# ...

# %%
V1_scaled = V1 * 3

print(V1_scaled)
# Out:
# [0.00650938769337317, 0.017223899505941054, 0.02035454639514933, 0.02592395522879898, 0.027792404535943005, 0.0399402986852877, 0.04362582417400773, 0.09467369752953525, 0.10877002030224747, 0.11020251083263233, 0.1251855321159845, 0.1263756591707127, 0.13435640280480154, 0.14336763863015012, 0.15870958809332936, 0.15891204077278498, 0.16609254514533367, 0.1813036567522217, 0.1876726522755804, 0.1905991628588345, 0.19093224895105576, 0.20899805365269253, 0.21261260029907025, 0.21289237156108642, 0.2282218151672003, 0.22996850719419804, 0.23071176850884256, 0.23775503870707937, 0.24373811360160524, 0.24589336368024572, 0.26148014247600315, 0.27741629065151086, 0.2830863743337192, 0.31785663248735396, 0.32925766226146624, 0.348318339815314, 0.34919229623792436, 0.349742016502949, 0.36930620912814904, 0.37883358225771413, 0.4003440456019416, 0.40035497017083965, 0.41700411307669516, 0.42099911869050377, 0.4236643610885711, 0.44209278065405944, 0.44341659311479253, 0.4466532031383549, 0.
# ...

# %%
import numpy as np

print(np.mean(V1))
print(np.std(V1))
# Out:
# 0.5149231513143985
# 0.2664192614688223

# %%
import random
import numpy as np

matrix = np.zeros((4, 3))

for i in range(4):
  for j in range(3):
    matrix[i][j] = random.random()
array = matrix.flatten()

print(matrix)
print(array)
# Out:
# [[0.442453   0.07144532 0.3113464 ]
#  [0.28179515 0.85288441 0.35325714]
#  [0.00456698 0.79235041 0.59875951]
#  [0.11919573 0.87896757 0.26692741]]
# [0.442453   0.07144532 0.3113464  0.28179515 0.85288441 0.35325714
#  0.00456698 0.79235041 0.59875951 0.11919573 0.87896757 0.26692741]

# %%
import random
import numpy as np


S1 = "I am a great learner. I am going to have an awesome life."
substring = "Am"
count = S1.lower().count(substring.lower())
print(f"The substring '{substring}' occurs {count} times in the string.")
# Out:
# The substring 'Am' occurs 2 times in the string.
